# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(' https://raw.githubusercontent.com/PGaea/ButardoPrincessGaea_BSIS2/main/SALARY_DATA.csv')

# %%
print(df)
# Out:
#     Employee ID     Name  Age Department  Salary
# 0             1   Alice    45         HR   54000
# 1             2      Bob   52         IT   78000
# 2             3  Charlie   37    Finance   66000
# 3             4    David   28  Marketing   72000
# 4             5      Eva   41      Sales   85000
# 5             6    Frank   53         IT   90000
# 6             7   Grace    32    Finance   62000
# 7             8    Henry   25         HR   40000
# 8             9      Ivy   48      Sales   94000
# 9            10     Jack   39  Marketing   70000
# 10           11    Karen   29         IT   65000
# 11           12      Leo   44    Finance   86000
# 12           13     Mona   33         HR   47000
# 13           14     Nina   51      Sales   88000
# 14           15   Oscar    36  Marketing   56000

# %%
salary = df['Salary'].to_numpy()

# %%
mean_salary = np.mean(salary)

# %%
print(mean_salary)
# Out:
# 70200.0

# %%
median_salary = np.median(salary)

# %%
print(median_salary)
# Out:
# 70000.0

# %%
std_salary = np.std(salary)

# %%
print(std_salary)
# Out:
# 15988.32907675679

# %%
total = np.sum(salary)

# %%
print(total)
# Out:
# 1053000

# %%
sns.histplot(df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
plt.show()

# %%
df1 = sns.catplot(data=df, col = "Name", x = "Salary",kind = "count")

# %%
df_h = df.groupby(['Name', 'Salary']).size().head(10)

# %%
(df_h.head())
# Out:
# Name     Salary
# Alice    54000     1
# Bob      78000     1
# Charlie  66000     1
# David    72000     1
# Eva      85000     1
# dtype: int64

# %%
top_5 = df_h.sort_values(ascending=False).head(5)

# %%
top_5.plot(kind='bar')
plt.title('Total Salary')
plt.xlabel('Name')
plt.ylabel('Highest Salary')
# Out:
# Text(0, 0.5, 'Highest Salary')

# %%
plt.show()

# %%
df_n = df.groupby(['Department']).size().head(10)

# %%
print(df_n)
# Out:
# Department
# Finance      3
# HR           3
# IT           3
# Marketing    3
# Sales        3
# dtype: int64

# %%
df_n.plot(kind='pie')
plt.title('Department')
plt.show()

# %%
df_n.plot(kind='line')
plt.title('Department')
plt.show()

# %%
df_s = df.groupby(['Salary']).size().head(10)

# %%
df_s.plot(kind='line')
plt.title('Total Salary')
plt.show()

# %%
df_s.plot(kind='pie')
plt.title('Total Salary')
plt.show()

# %%
age_info = df[df['Age'].notnull()][['Age']]

#Dropping values of age = 0
age_info_clean = age_info[age_info['Age'] != 0]

age_info_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     15 non-null     int64
# dtypes: int64(1)
# memory usage: 248.0 bytes

# %%
fig = plt.figure(figsize = (20,8))
Age_plot = sns.distplot(age_info_clean, bins = 30)
Age_plot.tick_params(labelsize = 13)
std = age_info['Age'].std()
plt.xlabel('Age', fontdict = {'fontsize':15})
plt.title('Age of disease-affected humans', fontdict = {'fontsize':15})
plt.bold=True
plt.axvline(std,color = 'red')
plt.show()
# Out:
# <ipython-input-130-b1eaf4ad02d5>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   Age_plot = sns.distplot(age_info_clean, bins = 30)
